# %% [markdown]
# ERRORS:
#
# * Why

# %%
import pandas as pd

# %%
f_df = pd.read_csv("f.csv")
h56_df = pd.read_csv("h56.csv")
harness_df = pd.read_csv("harness.csv")

# %%
f_df
# Out:
#                              tuple  count    G_test
# 0                     (0, 0, 0, 0)      0  0.036788
# 1         (0.01, 0.01, 0.01, 0.01)      0  0.036801
# 2     (-0.01, -0.01, -0.01, -0.01)      4  0.000012
# 3  (-0.01, -0.01, -0.01, -0.01, 1)      4  0.000012
# 4     (0.01, 0.01, 0.01, 0.01, -1)      1  0.100000
# 5      (0.01, 0.01, 0.01, 0.01, 1)      0  0.036801
# 6         (-0.5, -0.5, -0.5, -0.5)      4  0.000012

# %%
h56_df
# Out:
#                    G  iterations  optimized val  edges cut by config  \
# 0             G_test           0  -1.645856e+02                  192
# 1             G_test           2  -1.794589e+02                  122
# 2             G_test          10  -1.629069e+02                  178
# 3             G_test           0  -1.446039e+02                  110
# 4          G_sigmoid           0  -1.920000e+02                  192
# 5          G_sigmoid           2  -9.600000e+01                  130
# 6          G_sigmoid         143  -1.819873e+02                  182
# 7          G_sigmoid           0  -1.100000e+02                  110
# 8         G_relu_sum           1  -2.682906e+07                  136
# 9         G_relu_sum           1  -2.577578e+07                  134
# 10        G_relu_sum          51  -4.609091e+01                  174
# 11        G_relu_sum          19  -7.499999e+01                  110
# 12       G_relu_prod           0  -1.920000e+02                  192
# ...

# %%
edge_c = lambda d: d*2**(d-1)
harness_df["performance"] = harness_df["count"] / harness_df.d.map(edge_c)

# %%
harness_df.loc[harness_df.reg.isna(),"reg"] = "None"

# %%
harness_df[harness_df.d==5]
# Out:
#      (k,d)  d                 G            reg  count  \
# 40  (5, 5)  5            G_test           None     68
# 41  (5, 5)  5            G_test          ridge     69
# 42  (5, 5)  5            G_test  bound_sigmoid     68
# 43  (5, 5)  5            G_test  bound_softmax     28
# 44  (5, 5)  5         G_sigmoid           None     65
# 45  (5, 5)  5         G_sigmoid          ridge     65
# 46  (5, 5)  5         G_sigmoid  bound_sigmoid     70
# 47  (5, 5)  5         G_sigmoid  bound_softmax     50
# 48  (5, 5)  5        G_relu_sum           None     60
# 49  (5, 5)  5        G_relu_sum          ridge     61
# 50  (5, 5)  5        G_relu_sum  bound_sigmoid     71
# 51  (5, 5)  5        G_relu_sum  bound_softmax     48
# 52  (5, 5)  5       G_relu_prod           None     69
# 53  (5, 5)  5       G_relu_prod          ridge     62
# 54  (5, 5)  5       G_relu_prod  bound_sigmoid     65
# 55  (5, 5)  5       G_relu_prod  bound_softmax     48
# ...

# %%
harness_df[(harness_df["G"]=="G_test") & (harness_df["reg"]=="ridge")]
# Out:
#      (k,d)  d       G    reg  count                   filename  \
# 1   (3, 3)  3  G_test  ridge      6   data_test/harness_small1
# 21  (4, 4)  4  G_test  ridge     30  data_test/harness_small21
# 41  (5, 5)  5  G_test  ridge     69  data_test/harness_small41
# 61  (5, 6)  6  G_test  ridge    152  data_test/harness_small61
#
#            intersections  performance
# 1              (4, 4, 4)     0.500000
# 21      (12, 12, 12, 12)     0.937500
# 41  (23, 27, 26, 20, 16)     0.862500
# 61  (52, 60, 60, 36, 40)     0.791667

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
g = sns.FacetGrid(harness_df, col="d", row="reg")
g.map(sns.barplot, "G", "performance")
for ax in g.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
# Out:
# /home/uforanch/anaconda3/lib/python3.13/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /tmp/ipykernel_94884/1078751144.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
# /tmp/ipykernel_94884/1078751144.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
# /tmp/ipykernel_94884/1078751144.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
# ...

# %% [markdown]
# Can't get the labels working for now
#
# Bound sigmoid with G_sigmoid works well
# Relu prod with no or ridge reg works well
#
# Other performances are mediocre or inconsistent
#
# As seen above, G_relu_prod(_100) SHOULD work the worst (behaves the least like the discrete counting function) but it's pretty good in practice.

# %%
np.load("data/t1_matrix_test_16.npy")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 np.load("data/t1_matrix_test_16.npy")
#
# NameError: name 'np' is not defined

# %%
np.load("data/t1_matrix_test_18.npy")

# %%
np.log(1+np.exp(np.array([-.4,.5,2])))
