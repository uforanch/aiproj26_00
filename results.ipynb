# %%
import pandas as pd

# %%
f_df = pd.read_csv("f.csv")
h56_df = pd.read_csv("h56.csv")
harness_df = pd.read_csv("harness.csv")

# %%
f_df
# Out:
#                              tuple  count  G_original  G_sigmoid  G_relu_sum
# 0                     (0, 0, 0, 0)      0    0.000000   0.500000        0.00
# 1         (0.01, 0.01, 0.01, 0.01)      0    0.000000   0.268941        0.00
# 2     (-0.01, -0.01, -0.01, -0.01)      4    0.039801   0.731059        0.04
# 3  (-0.01, -0.01, -0.01, -0.01, 1)      4    0.039801   0.731059        0.04
# 4     (0.01, 0.01, 0.01, 0.01, -1)      1    0.693147   1.000000        1.00
# 5      (0.01, 0.01, 0.01, 0.01, 1)      0    0.000000   0.268941        0.00
# 6         (-0.5, -0.5, -0.5, -0.5)      4    1.621860   1.000000        2.00

# %%
h56_df
# Out:
#              G  iterations  optimized val  edges cut by config  \
# 0   G_original          30  -8.851915e+03                   60
# 1   G_original          13  -3.843888e+02                   60
# 2   G_original          17  -6.694284e+01                   60
# 3   G_original           5  -6.134109e+01                   60
# 4    G_sigmoid           0  -6.000000e+01                   60
# 5    G_sigmoid           0  -2.500000e+01                   60
# 6    G_sigmoid          82  -1.487374e+02                  150
# 7    G_sigmoid           0  -6.000000e+01                   60
# 8   G_relu_sum          13 -1.049458e+292                  152
# 9   G_relu_sum           2  -1.842417e+08                   60
# 10  G_relu_sum          17  -7.499976e+01                   60
# 11  G_relu_sum           4  -6.806250e+01                   60
#
#     optimize func of t1 regularization                    filename
# 0           -568.163703            NaN   data/t1_matrix_test_0.npz
# ...

# %%
harness_df
# Out:
#      (k,d)           G            reg        count                  filename
# 0   (3, 3)  G_original            NaN    tensor(0)   data/harness_small0.npz
# 1   (3, 3)  G_original          ridge    tensor(7)   data/harness_small1.npz
# 2   (3, 3)  G_original  bound_sigmoid    tensor(0)   data/harness_small2.npz
# 3   (3, 3)  G_original  bound_softmax    tensor(0)   data/harness_small3.npz
# 4   (3, 3)   G_sigmoid            NaN    tensor(0)   data/harness_small4.npz
# 5   (3, 3)   G_sigmoid          ridge    tensor(0)   data/harness_small5.npz
# 6   (3, 3)   G_sigmoid  bound_sigmoid    tensor(9)   data/harness_small6.npz
# 7   (3, 3)   G_sigmoid  bound_softmax    tensor(9)   data/harness_small7.npz
# 8   (3, 3)  G_relu_sum            NaN    tensor(0)   data/harness_small8.npz
# 9   (3, 3)  G_relu_sum          ridge    tensor(7)   data/harness_small9.npz
# 10  (3, 3)  G_relu_sum  bound_sigmoid    tensor(0)  data/harness_small10.npz
# ...
